# %% [markdown]
# October 21, 2025 notes and code

# %% [markdown]
# -Visualization is important as it can be easier to see trends and it is easier to share our
# findings with people.
# -Important to get it right as it can affect lives and well-being
# -Visual examples:
# 1) Life expectancy chart not great. Hard to align chart to ages, odd dimenson of graph. Shadows
# make it harder to read. Use fo 3-D is unnecessary. Age is in odd incriments.Poor choice of font.
# 2) Monstrous costs graph is a poor choice for a professional graph. Comical and hard to read.
# Wont take it seriously. Image could create bias as it could be seen as bad. Hard to see if
# there is a dollar sign on the tongue. While we had critiques, it is getting its point across
# and is a good use of visuals.
# 3) No title. What is it trying to show us? Ratio can make the data appear different and more or
# less significant.No access labels. No units.Clear, simple, neutral.
# 4) 2012 Presidential run. The data is not adding up as it exceeds 100%.It's not clear what is the graph is showing. The 63% appears ot be larger than the 60%.Blue on blue is hard to read. Source tells us nothing.
# 5) Wind map. Animation is cool. Lacks colour. It's intuitive.
# 3 points to keep in mind - Aesthetic, Substantive, Perceptual. Weight of these depends on the context.
# -Context - where/how
# -Audience
# -Data sructure
# -No hard and fast rules, need to make decisions based on the context
# -Can be hand drawn but for professional purposes will use a software
# - Excel/Sheets - not reproduceable
# - Tableau - not reproduceable
# - Power BI - used a lot for business intelligence, not reproduceable.
# - R - Free, codinglanguage, reproduceable, popular in acadeic context, can do data anlysis as well as vizualization, more of a learnign curve, but can do a lot of cool things
# - Python - Free, codinglanguage, reproduceable, popular in many industries, can do data anlysis and vizualization
#
# Figure = entire thing
# Plot - our axes - NOT the same as x and y on our graph

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import scipy
import PIL
import requests
import seaborn as sns

# %%
#Generate sample data 
np.random.seed(613)
#Give us 50 values 0 - 49
x = np.arange(50)
#Give us 50 random integers between 0 and 100
y = np.random.randint(0,100,50)
#Set the size of our figure
fig, ax = plt.subplots(figsize=(5, 3))
#Create a Scatter plot
ax.scatter(x,y)

# %%
#Create a Line plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

# %%
#Create a Bar chart
fig, ax = plt.subplots(figsize=(5, 3))
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
#Create a Horizontal bar chart
fig, ax = plt.subplots(figsize=(5, 3))      
ax.barh(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
#Generate sample data 
np.random.seed(613)
#Give us 50 values 0 - 49
x = np.arange(50)
#Give us 50 random integers between 0 and 100
y = np.random.randint(0,100,50)
#Size of our figure
fig, ax = plt.subplots(figsize=(5, 3))
#Create a Histogram - counts occurances of values in y
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
#Generate sample data 
np.random.seed(613)
#Give us 50 values 0 - 49
x = np.arange(50)
#Give us 50 random integers between 0 and 100
y = np.random.randint(0,100,50)
#Set the size of our figure
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
#Add title to our graph 
ax.set_title('Total growth over time')
#Add x and y labels to the graph 
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
# Out:
# Text(0.5, 0, 'Years since start')

# %%
#Modify the labels font properties
font1 = {'family':'sans-serif','color':'blue','size':20}
font2 = {'family':'monospace','color':'green','size':14}

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict=font1)
ax.set_ylabel('Total growth', fontdict=font2)   
ax.set_xlabel('Years since start', fontdict=font2)
# Out:
# Text(0.5, 0, 'Years since start')

# %%
#Moving labels and titles by changing alignment and position

font1 = {'family':'sans-serif','color':'blue','size':20}
font2 = {'family':'monospace','color':'green','size':14}

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict=font1, loc='left')
ax.set_ylabel('Total growth', fontdict=font2)   
ax.set_xlabel('Years since start', fontdict=font2)
# Out:
# Text(0.5, 0, 'Years since start')

# %%
#Make a scatter plot with different marker and color
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y, marker = '*', color = "indigo")

# %%
#Modifying data points by changing colour, adding connecting lines
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,
        y, 
        marker='*', #NEW ADDITIONS
        color = "pink") #NEW ADDITIONS
fig.show()
# Out:
# C:\Users\werne\AppData\Local\Temp\ipykernel_36172\2986309037.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
#Modifying data points by changing colour, adding connecting lines
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y,
        marker = '*',
        color = "fuchsia",
        linestyle='--',
        linewidth=2)

# %%
#Generate sample data 
np.random.seed(613)
#Give us 50 values 0 - 49
x = np.arange(50)
#Give us 50 random integers between 0 and 100
y = np.random.randint(0,100,50)
#Size of our figure
fig, ax = plt.subplots(figsize=(5, 3))
# color being new addition
ax.plot(x,y,
        marker = '*',
        markersize = 12,
        color = "indigo",
        linestyle='--',
        linewidth=2, #change line thickness
        markeredgecolor='#fa9359', #change marker edge color
        markerfacecolor='#000000') #change marker face color
fig.show()
# Out:
# C:\Users\werne\AppData\Local\Temp\ipykernel_36172\425633473.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
#Adding gridlines
fig, ax = plt.subplots(figsize=(5, 3))
ax.grid(axis = 'y')
ax.grid(axis = 'y', color = "blue", linewidth = 2, linestyle = '-.')

# %%
#Play with the python graph gallery
#Creating a Swarm plot
sns.swarmplot(y=y)
plt.show()

# %%
#Play with the python graph gallery

#Generate sample data 
np.random.seed(613)
#Give us 50 values 0 - 49
x = np.arange(50)
#Give us 50 random integers between 0 and 100
y = np.random.randint(0,100,50)

# LAST STEP ADDED - Reorder the dataframe by value to understand rank quicker
df = df.sort_values(by= ['Value'])
#Basic barplot
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)

#remove grid and spines
plt.axis('off')

#set the coordinates limites
upperLimit = 100
lowerLimit = 30

#Compute max and min in the dataset
max = df['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerlimit) / max
heights = slope * df.Value + lowerlimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="red",
    color = "pink",
    )

#add labels
labelPadding = 6

for bar, angle, height, label in zip(bars, angles, heights, df["Name"]):
    #rotation = np.rad2deg(angle)
    rotation = np.rad2deg(angle - width/2)
    alignment = ""
    # If the label is in the first half of the circle
    if angle >= np.pi/2 and angle <= 3*np.pi/2:
        # Flip the label upside down
        rotation = rotation + 180
        alignment = "right"
    else:
        alignment = "left"
    
    # Finally add the label
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center',
        rotation=rotation,
        rotation_mode="anchor"
        )
    
    #

# %% [markdown]
# October 22, 2025 notes and code

# %% [markdown]
# **Added comments to code above for today's notes with "#" **
# - I could not see the image manipualtions on my own. I would never have picked it up on my own if I was reviewing it.
# - Write your code in something you can run it in, if you do it in word it can change the punctuation
# - Standard practise should be to comment on code as you go, as it makes it easier to undertand/maintain/update. Makes it easier for people to work on later, especially if a lot of time has gone by or the author is not available anymore.
# -Can add when it was last worked on, who worked on it. Useful for collaboration.
# - Package version numbers can be useful too.
# - Can add units, variables, what they represent, anything that can make it easier for other to understand, and for me to underatand later what I was doing.
# - MIT Coding and commenting guide - https://mitcommlab.mit.edu/broad/commkit/coding-and-comment-style/
# - Comments need to be updated too!
# - FAIR principles (findability, accessibility, interoperability, reusability)
# - Slide for 4 - Page 27 to 29 - useful for deciding on which visual to use
